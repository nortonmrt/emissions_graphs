# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# alimentações: 34, 114, 194, 274

matplotlib.rc('font', family = 'Times New Roman')
matplotlib.rc('font', size = 14)


data = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/3Phi0,7/emissoes3.xlsx")
temperature = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/3Phi0,7/tempo3.xlsx")

seg = list(data['seg'])
ppm_CO = list(data['ppm CO'])
ppm_NOx = list(data['ppm NOx'])
ppm_CxHy = list(data['ppm CxHy'])
percentage_CO2 = list(data['% CO2IR'])
percentage_O2 = list(data['% O2'])
temperatures = list(temperature['temperature'])

# plt.figure(figsize=(20,10))
# plt.plot(seg,ppm_CO,label = "CO (ppm)")
# plt.plot(seg,ppm_NOx,label = "NOx (ppm)")
# plt.title("Emissões para ")
# plt.show()

############
fig, (ax, ax2, ax3) = plt.subplots(3,1, figsize=(15,20))
#fig.suptitle('Emissões')

ax_c = ax.twinx()
  
line1, = ax.plot(seg, ppm_CO, 'r', dashes=[8, 4],label = 'CO')
ax.plot([34,34],[0,600],'b',dashes=[10, 10])
ax.plot([114,114],[0,600],'b',dashes=[10, 10])
ax.plot([194,194],[0,600],'b',dashes=[10, 10])
ax.plot([274,274],[0,600],'b',dashes=[10, 10])
line2, = ax_c.plot(seg, ppm_NOx, dashes=[1, 2],label = 'NOx')
ax.legend(loc='lower left')
ax_c.legend(loc='lower right')
ax_c.set_ylim([0,150])
#ax.set_ylim([0,2800])
#line3, = ax.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'CxHy')

ax.set(xlabel='Tempo (s)', ylabel='Concentração de CO (ppm)', title='Concentrações de NOx e CO')
ax_c.set(ylabel='Concentração NOx (ppm)')

ax_d = ax2.twinx()

line4, = ax2.plot(seg, percentage_CO2, dashes=[1,2], label = '%CO2' )
line5, = ax_d.plot(seg, percentage_O2,'r', dashes=[4,8], label = '%O2' )
ax2.plot([34,34],[1.2,2.6],'b',dashes=[10, 10])
ax2.plot([114,114],[1.2,2.6],'b',dashes=[10, 10])
ax2.plot([194,194],[1.2,2.6],'b',dashes=[10, 10])
ax2.plot([274,274],[1.2,2.6],'b',dashes=[10, 10])
ax2.set(xlabel='Tempo (s)', ylabel='Concentração de CO2 (%)', title='Concentrações de CO2 e O2')
ax_d.set(ylabel='Concentração de O2 (%)')

ax_d.legend(loc='lower right')
ax2.legend(loc='lower left')
#ax2.grid()


#ax.grid()

ax_e = ax3.twinx()

line6, = ax3.plot(seg, temperatures, 'r', label = 'Temperatura' )
line7, = ax_e.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'Hidrocarbonetos')
ax3.set(xlabel='Tempo (s)', ylabel='Temperatura (°C)', title='Temperatura e concentração de hidrocarbonetos')
ax_e.set(ylabel='Concentração de hidrocarbonetos (ppm)')
ax3.plot([34,34],[570,630],'b',dashes=[10, 10])
ax3.plot([114,114],[570,630],'b',dashes=[10, 10])
ax3.plot([194,194],[570,630],'b',dashes=[10, 10])
ax3.plot([274,274],[570,630],'b',dashes=[10, 10])

ax_e.set_ylim([2300,2600])
ax_e.legend(loc = 'lower right')
ax3.legend(loc = 'lower left')


#fig.savefig("test.png")
plt.show()

# %%
emissoes_7 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/7Phi0,7/emissoes7.xlsm")
temperature_7 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/7Phi0,7/tempo7.xlsm")

seg = list(emissoes_7['tempo'])
ppm_CO = list(emissoes_7['ppm CO'])
ppm_NOx = list(emissoes_7['ppm NOx'])
ppm_CxHy = list(emissoes_7['ppm CxHy'])
percentage_CO2 = list(emissoes_7['% CO2IR'])
percentage_O2 = list(emissoes_7['% O2'])
temperatures = list(temperature_7['temperature_7'])

# plt.figure(figsize=(20,10))
# plt.plot(seg,ppm_CO,label = "CO (ppm)")
# plt.plot(seg,ppm_NOx,label = "NOx (ppm)")
# plt.title("Emissões para ")
# plt.show()

############
fig, (ax, ax2, ax3) = plt.subplots(3,1, figsize=(15,20))
#fig.suptitle('Emissões')

ax_c = ax.twinx()
  
line1, = ax.plot(seg, ppm_CO, 'r', dashes=[8, 4],label = 'CO')
ax.plot([34,34],[0,600],'b',dashes=[10, 10])
ax.plot([114,114],[0,600],'b',dashes=[10, 10])
ax.plot([194,194],[0,600],'b',dashes=[10, 10])
ax.plot([274,274],[0,600],'b',dashes=[10, 10])
line2, = ax_c.plot(seg, ppm_NOx, dashes=[1, 2],label = 'NOx')
ax.legend(loc='upper left')
ax_c.legend(loc='upper right')
ax_c.set_ylim([0,80])
#ax.set_ylim([0,2800])
#line3, = ax.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'CxHy')

ax.set(xlabel='Tempo (s)', ylabel='Concentração de CO (ppm)', title='NOx, CO')
ax_c.set(ylabel='Concentração NOx (ppm)')

####################################
ax_d = ax2.twinx()

line4, = ax2.plot(seg, percentage_CO2, dashes=[1,2], label = '%CO2' )
line5, = ax_d.plot(seg, percentage_O2,'r', dashes=[4,8], label = '%O2' )
# ax2.plot([34,34],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([114,114],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([194,194],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([274,274],[1.2,2.6],'b',dashes=[10, 10])
ax2.set(xlabel='Tempo (s)', ylabel='Concentração de CO2 (%)', title='Concentração de CO2 e O2')
ax_d.set(ylabel='Concentração de O2 (%)')

ax_d.legend(loc='upper right')
ax2.legend(loc='upper left')
#ax2.grid()


#ax.grid()

####################################
ax_e = ax3.twinx()

line6, = ax3.plot(seg, temperatures, 'r', label = 'Temperatura' )
line7, = ax_e.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'Hidrocarbonetos')
ax3.set(xlabel='Tempo (s)', ylabel='Temperatura (oC)', title='Temperatura e concentração de hidrocarbonetos')
ax_e.set(ylabel='Concentração de hidrocarbonetos (ppm)')
# ax3.plot([34,34],[570,630],'b',dashes=[10, 10])
# ax3.plot([114,114],[570,630],'b',dashes=[10, 10])
# ax3.plot([194,194],[570,630],'b',dashes=[10, 10])
# ax3.plot([274,274],[570,630],'b',dashes=[10, 10])

ax_e.set_ylim([2300,2600])
ax_e.legend(loc = 'upper right')
#ax3.legend(loc = 'upper left')


#fig.savefig("test.png")
plt.show()

# %%
temperature_7 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/estabilizacao7.xlsm")
temperature_5 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/estabilizacao5.xlsm")
temperature_3 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/estabilizacao3.xlsm")

seg = list(temperature_7['tempo'])
temperatures_7 = list(temperature_7['temperatura'])
temperatures_5 = list(temperature_5['temperatura'])
temperatures_3 = list(temperature_3['temperatura'])

# plt.figure(figsize=(20,10))
# plt.plot(seg,ppm_CO,label = "CO (ppm)")
# plt.plot(seg,ppm_NOx,label = "NOx (ppm)")
# plt.title("Emissões para ")
# plt.show()

############

plt.figure(figsize=(12,8))
plt.plot(seg,temperatures_7,'b',label = "Potência 7")
plt.plot(seg,temperatures_5,'r',label = "Potência 5")
plt.plot(seg,temperatures_3,'g',label = "Potência 3")

#plt.title("Emissões para ")
plt.plot([0,1501],[604,604],'g',dashes=[10, 10])
plt.plot([0,1501],[570.61,570.61],'r',dashes=[10, 10])
plt.plot([0,1501],[549.38,549.38],'b',dashes=[10, 10])

plt.xlabel('Tempo (s)')
plt.ylabel('Temperatura (°C)')
plt.ylim([400,700])

plt.grid()
plt.legend()
plt.show()

# %%
#5
emissoes_5 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/5Phi0,7/emissoes5.xlsm")
temperature_5 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/5Phi0,7/tempo5.xlsm")

seg = list(emissoes_5['tempo'])
ppm_CO = list(emissoes_5['ppm CO'])
ppm_NOx = list(emissoes_5['ppm NOx'])
ppm_CxHy = list(emissoes_5['ppm CxHy'])
percentage_CO2 = list(emissoes_5['% CO2IR'])
percentage_O2 = list(emissoes_5['% O2'])
temperatures = list(temperature_5['temperatura'])


# plt.figure(figsize=(20,10))
# plt.plot(seg,ppm_CO,label = "CO (ppm)")
# plt.plot(seg,ppm_NOx,label = "NOx (ppm)")
# plt.title("Emissões para ")
# plt.show()

############
fig, (ax, ax2, ax3) = plt.subplots(3,1, figsize=(15,20))
#fig.suptitle('Emissões')

ax_c = ax.twinx()
  
line1, = ax.plot(seg, ppm_CO, 'r', dashes=[8, 4],label = 'CO')
# ax.plot([34,34],[0,500],'b',dashes=[10, 10])
# ax.plot([114,114],[0,500],'b',dashes=[10, 10])
# ax.plot([194,194],[0,500],'b',dashes=[10, 10])
# ax.plot([274,274],[0,500],'b',dashes=[10, 10])
line2, = ax_c.plot(seg, ppm_NOx, dashes=[1, 2],label = 'NOx')
ax.legend(loc='lower left')
ax_c.legend(loc='lower right')
ax_c.set_ylim([0,100])
#ax.set_ylim([0,2800])
#line3, = ax.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'CxHy')

ax.set(xlabel='Tempo (s)', ylabel='Concentração de CO (ppm)', title='Concentrações de NOx e CO')
ax_c.set(ylabel='Concentração NOx (ppm)')

ax_d = ax2.twinx()

line4, = ax2.plot(seg, percentage_CO2, dashes=[1,2], label = '%CO2' )
line5, = ax_d.plot(seg, percentage_O2,'r', dashes=[4,8], label = '%O2' )
# ax2.plot([34,34],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([114,114],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([194,194],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([274,274],[1.2,2.6],'b',dashes=[10, 10])
ax2.set(xlabel='Tempo (s)', ylabel='Concentração de CO2 (%)', title='Concentrações de CO2 e O2')
ax_d.set(ylabel='Concentração de O2 (%)')

ax_d.legend(loc='lower right')
ax2.legend(loc='lower left')
#ax2.grid()


#ax.grid()

ax_e = ax3.twinx()

line6, = ax3.plot(seg, temperatures, 'r', label = 'Temperatura' )
line7, = ax_e.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'Hidrocarbonetos')
ax3.set(xlabel='Tempo (s)', ylabel='Temperatura (°C)', title='Temperatura e concentração de hidrocarbonetos')
ax_e.set(ylabel='Concentração de hidrocarbonetos (ppm)')
# ax3.plot([34,34],[570,630],'b',dashes=[10, 10])
# ax3.plot([114,114],[570,630],'b',dashes=[10, 10])
# ax3.plot([194,194],[570,630],'b',dashes=[10, 10])
# ax3.plot([274,274],[570,630],'b',dashes=[10, 10])

ax_e.set_ylim([2200,2700])
ax_e.legend(loc = 'lower right')
ax3.legend(loc = 'lower left')


#fig.savefig("test.png")
plt.show()

# %%
# 7

emissoes_7 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/7Phi0,7/emissoes7.xlsm")
temperature_7 = pd.read_excel("C:/Users/Cliente Especial/Desktop/Documentos TCC/Emissões temp phi 0,7/7Phi0,7/tempo7.xlsm")

seg = list(emissoes_7['tempo'])
ppm_CO = list(emissoes_7['ppm CO'])
ppm_NOx = list(emissoes_7['ppm NOx'])
ppm_CxHy = list(emissoes_7['ppm CxHy'])
percentage_CO2 = list(emissoes_7['% CO2IR'])
percentage_O2 = list(emissoes_7['% O2'])
temperatures = list(temperature_7['temperature_7'])


# plt.figure(figsize=(20,10))
# plt.plot(seg,ppm_CO,label = "CO (ppm)")
# plt.plot(seg,ppm_NOx,label = "NOx (ppm)")
# plt.title("Emissões para ")
# plt.show()

############
fig, (ax, ax2, ax3) = plt.subplots(3,1, figsize=(15,20))
#fig.suptitle('Emissões')

ax_c = ax.twinx()
  
line1, = ax.plot(seg, ppm_CO, 'r', dashes=[8, 4],label = 'CO')
# ax.plot([75,75],[50,550],'b',dashes=[10, 10])
# ax.plot([257,257],[50,550],'b',dashes=[10, 10])
# ax.plot([332,332],[50,550],'b',dashes=[10, 10])
# ax.plot([274,274],[50,550],'b',dashes=[10, 10])
line2, = ax_c.plot(seg, ppm_NOx, dashes=[1, 2],label = 'NOx')
ax.legend(loc='lower left')
ax_c.legend(loc='lower right')
ax_c.set_ylim([0,80])
#ax.set_ylim([0,2800])
#line3, = ax.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'CxHy')

ax.set(xlabel='Tempo (s)', ylabel='Concentração de CO (ppm)', title='Concentrações de NOx e CO')
ax_c.set(ylabel='Concentração NOx (ppm)')

ax_d = ax2.twinx()

line4, = ax2.plot(seg, percentage_CO2, dashes=[1,2], label = '%CO2' )
line5, = ax_d.plot(seg, percentage_O2,'r', dashes=[4,8], label = '%O2' )
# ax2.plot([34,34],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([114,114],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([194,194],[1.2,2.6],'b',dashes=[10, 10])
# ax2.plot([274,274],[1.2,2.6],'b',dashes=[10, 10])
ax2.set(xlabel='Tempo (s)', ylabel='Concentração de CO2 (%)', title='Concentrações de CO2 e O2')
ax_d.set(ylabel='Concentração de O2 (%)')

ax_d.legend(loc='lower right')
ax2.legend(loc='lower left')
#ax2.grid()


#ax.grid()

ax_e = ax3.twinx()

line6, = ax3.plot(seg, temperatures, 'r', label = 'Temperatura' )
line7, = ax_e.plot(seg, ppm_CxHy, 'g', dashes=[4, 3],label = 'Hidrocarbonetos')
ax3.set(xlabel='Tempo (s)', ylabel='Temperatura (°C)', title='Temperatura e concentração de hidrocarbonetos')
ax_e.set(ylabel='Concentração de hidrocarbonetos (ppm)')
# ax3.plot([34,34],[570,630],'b',dashes=[10, 10])
# ax3.plot([114,114],[570,630],'b',dashes=[10, 10])
# ax3.plot([194,194],[570,630],'b',dashes=[10, 10])
# ax3.plot([274,274],[570,630],'b',dashes=[10, 10])

ax_e.set_ylim([2300,2600])
ax_e.legend(loc = 'lower right')
ax3.legend(loc = 'lower left')


#fig.savefig("test.png")
plt.show()
